# %% [markdown]
# # Network Visualization - Verbal fluency data: animals

# %% [markdown]
# ## I. Data preparation

# %%
# load libraries
library(igraph)
library(scales)
library(lmSupport)
library(beepr)
library(RColorBrewer)
library(qgraph)
# Out:
# Warning message:
# "package 'qgraph' was built under R version 3.5.3"

# %%
# Read in "animal" data
nodes <- read.csv("data/animal/animals_min5_directed_Nodes.csv", header=T, as.is=T)
links <- read.csv("data/animal/c05_st_red_anim_min5_dir_edges.csv", header=T, as.is=T)

# %%
# Examine the data:
head(nodes)
head(links)
# Out:
#   Id        Label     Eigenvector.Centrality Modularity.Class Eccentricity
# 1 aardvark  aardvark  0.3608073               0               3
# 2 allig     allig     0.7445333               1               3
# 3 ant       ant       0.4742405              23               3
# 4 anteat    anteat    0.3467267               0               3
# 5 antelop   antelop   0.7801923               2               3
# 6 armadillo armadillo 0.3587843               0               3
#   Closeness.Centrality Betweenness.Centrality In.Degree Out.Degree Degree
# 1 1.904762               63.89300             39        43          82
# 2 1.721088             1306.30769             97        89         186
# 3 1.891156              747.47158             59        51         110
# 4 1.894558               84.14831             37        49          86
# 5 1.721088             1037.54843             93        92         185
# 6 1.925170              161.75615             40        43          83
#   Weighted.Degree Weighted.In.Degree Weighted.Out.Degree Authority
# 1  166             59                107                 0.003955696
# 2  767            388                379                 0.009691455
# 3  221            106                115                 0.005933544
# 4  153             73                 80                 0.003757911
# 5 1098            557                541                 0.009295886
# 6  124             62                 62                 0.004054589
#   Hub         Clustering.Coefficient Weighted.Clustering.Coefficient Strenght
# 1 0.003955696 0.6161202              0.3911944                        166
# 2 0.009691455 0.3342222              0.1738891                        767
# 3 0.005933544 0.3964167              0.2126282                        221
# 4 0.003757911 0.5600198              0.3255286                        153
# 5 0.009295886 0.3821393              0.1924670                       1098
# 6 0.004054589 0.4774705              0.2762589                        124
#   from     to        type     weight
# 1 aardvark allig     Directed 1
# 2 aardvark ant       Directed 7
# 3 aardvark anteat    Directed 7
# 4 aardvark antelop   Directed 2
# 5 aardvark armadillo Directed 2
# 6 aardvark baboon    Directed 2

# %%
# Converting the data to an igraph object
# Arguments:
# - d = edges (links)
# - vertices = nodes
# - directed = True (if directed graph)
net <- graph_from_data_frame(d=links, vertices=nodes, directed=T) 
is_weighted(net) # check if is weigthed
# Out:
# [1] TRUE

# %%
# Examine the resulting object
class(net)
net
# Out:
# [1] "igraph"
# IGRAPH 40b7cee DNW- 295 9817 --
# + attr: name (v/c), Label (v/c), Eigenvector.Centrality (v/n),
# | Modularity.Class (v/n), Eccentricity (v/n), Closeness.Centrality
# | (v/n), Betweenness.Centrality (v/n), In.Degree (v/n), Out.Degree
# | (v/n), Degree (v/n), Weighted.Degree (v/n), Weighted.In.Degree (v/n),
# | Weighted.Out.Degree (v/n), Authority (v/n), Hub (v/n),
# | Clustering.Coefficient (v/n), Weighted.Clustering.Coefficient (v/n),
# | Strenght (v/n), type (e/c), weight (e/n)
# + edges from 40b7cee (vertex names):
# [1] aardvark->allig     aardvark->ant       aardvark->anteat
# [4] aardvark->antelop   aardvark->armadillo aardvark->baboon
# + ... omitted several edges

# %% [markdown]
# The description of an igraph object is: *IGRAPH 2913da7 DN-- 295 9817 --*
#
# **Description**:
#  - D or U, for a directed or undirected graph
#  - N for a named graph (where nodes have a `name` attribute)
#  - W for a weighted graph (where edges have a `weight` attribute)
#  - B for a bipartite (two-mode) graph (where nodes have a `type` attribute)
#  - The two numbers that follow (295 9817) refer to the number of nodes and edges in the graph.
#  - The description also lists node & edge attributes

# %%
# We can access the nodes, edges, and their attributes:
E(net) # edges
V(net) # vertices
print("Attributes edges")
head(E(net)$type) # attributes edges
print("Attributes vertex")
head(V(net)$name) # attributes vertex
# Out:
# + 9817/9817 edges from 40b7cee (vertex names):
#  [1] aardvark->allig     aardvark->ant       aardvark->anteat
#  [4] aardvark->antelop   aardvark->armadillo aardvark->baboon
#  [7] aardvark->badger    aardvark->bat       aardvark->bear
# [10] aardvark->beaver    aardvark->buffalo   aardvark->camel
# [13] aardvark->canari    aardvark->cat       aardvark->cheetah
# [16] aardvark->chicken   aardvark->chipmunk  aardvark->cow
# [19] aardvark->coyot     aardvark->crocodil  aardvark->deer
# [22] aardvark->dog       aardvark->eleph     aardvark->elk
# [25] aardvark->fish      aardvark->fox       aardvark->frog
# [28] aardvark->goat      aardvark->hors      aardvark->kangaroo
# + ... omitted several edges
# + 295/295 vertices, named, from 40b7cee:
#   [1] aardvark      allig         ant           anteat        antelop
#   [6] armadillo     baboon        badger        bat           bear
#  [11] beaver        buffalo       camel         canari        cat
#  [16] cheetah       chicken       chipmunk      cow           coyot
#  [21] crocodil      deer          dog           eleph         elk
#  [26] fish          fox           frog          goat          hors
#  [31] kangaroo      lion          llama         monkei        octopus
#  [36] ostrich       rabbit        raccoon       sheep         snak
#  [41] tiger         turkei        whale         zebra         bird
#  [46] boa           bull          chameleon     chimp         cougar
# + ... omitted several vertices
# [1] "Attributes edges"
# [1] "Directed" "Directed" "Directed" "Directed" "Directed" "Directed"
# [1] "Attributes vertex"
# [1] "aardvark"  "allig"     "ant"       "anteat"    "antelop"   "armadillo"

# %%
# To access specific nodes and edges by attribute
V(net)[name=="aardvark"]
E(net)[type=="Directed"]
# Out:
# + 1/295 vertex, named, from 40b7cee:
# [1] aardvark
# + 9817/9817 edges from 40b7cee (vertex names):
#  [1] aardvark->allig     aardvark->ant       aardvark->anteat
#  [4] aardvark->antelop   aardvark->armadillo aardvark->baboon
#  [7] aardvark->badger    aardvark->bat       aardvark->bear
# [10] aardvark->beaver    aardvark->buffalo   aardvark->camel
# [13] aardvark->canari    aardvark->cat       aardvark->cheetah
# [16] aardvark->chicken   aardvark->chipmunk  aardvark->cow
# [19] aardvark->coyot     aardvark->crocodil  aardvark->deer
# [22] aardvark->dog       aardvark->eleph     aardvark->elk
# [25] aardvark->fish      aardvark->fox       aardvark->frog
# [28] aardvark->goat      aardvark->hors      aardvark->kangaroo
# + ... omitted several edges

# %%
# To extract an edge list or a matrix back from the igraph networks:
head(as_edgelist(net, names=T))
head(as_adjacency_matrix(net, attr="weight"))
# Out:
#      [,1]     [,2]
# [1,] aardvark allig
# [2,] aardvark ant
# [3,] aardvark anteat
# [4,] aardvark antelop
# [5,] aardvark armadillo
# [6,] aardvark baboon
# [1] 0 2 6 1 3 2

# %%
# To extract data frames describing nodes and edges:
head(as_data_frame(net, what="edges"))
head(as_data_frame(net, what="vertices"))
# Out:
#   from     to        type     weight
# 1 aardvark allig     Directed 1
# 2 aardvark ant       Directed 7
# 3 aardvark anteat    Directed 7
# 4 aardvark antelop   Directed 2
# 5 aardvark armadillo Directed 2
# 6 aardvark baboon    Directed 2
#           name      Label     Eigenvector.Centrality Modularity.Class
# aardvark  aardvark  aardvark  0.3608073               0
# allig     allig     allig     0.7445333               1
# ant       ant       ant       0.4742405              23
# anteat    anteat    anteat    0.3467267               0
# antelop   antelop   antelop   0.7801923               2
# armadillo armadillo armadillo 0.3587843               0
#           Eccentricity Closeness.Centrality Betweenness.Centrality In.Degree
# aardvark  3            1.904762               63.89300             39
# allig     3            1.721088             1306.30769             97
# ant       3            1.891156              747.47158             59
# anteat    3            1.894558               84.14831             37
# antelop   3            1.721088             1037.54843             93
# armadillo 3            1.925170              161.75615             40
#           Out.Degree Degree Weighted.Degree Weighted.In.Degree
# aardvark  43          82     166             59
# allig     89         186     767            388
# ant       51         110     221            106
# anteat    49          86     153             73
# antelop   92         185    1098            557
# armadillo 43          83     124             62
#           Weighted.Out.Degree Authority   Hub         Clustering.Coefficient
# aardvark  107                 0.003955696 0.003955696 0.6161202
# allig     379                 0.009691455 0.009691455 0.3342222
# ant       115                 0.005933544 0.005933544 0.3964167
# anteat     80                 0.003757911 0.003757911 0.5600198
# antelop   541                 0.009295886 0.009295886 0.3821393
# armadillo  62                 0.004054589 0.004054589 0.4774705
#           Weighted.Clustering.Coefficient Strenght
# aardvark  0.3911944                        166
# allig     0.1738891                        767
# ant       0.2126282                        221
# anteat    0.3255286                        153
# antelop   0.1924670                       1098
# armadillo 0.2762589                        124

# %% [markdown]
# ## II. Ploting experimentation

# %%
# First plot
plot(net)
# Out:
# Plot with title ""

# %%
# Compute node degrees (#links) and use that to set node size:
deg <- degree(net, mode="all")
deg = rescale(deg, to = c(5, 25))
V(net)$size <- deg
plot(net)
# Out:
# Plot with title ""

# %%
# Let's remove loops from the graph
net <- simplify(net, remove.multiple = F, remove.loops = T) 
# And reduce the arrow size and remove the labels:
plot(net, edge.arrow.size=.1,vertex.label=NA)
# Out:
# Plot with title ""

# %%
# Let's reduce arrow size, put labels back, and reuce label size 
plot(net, edge.arrow.size=.1, edge.curved=0.2,
     vertex.color="orange", vertex.frame.color="#555555",
     vertex.label=V(net)$name, vertex.label.color="black",
     vertex.label.cex=.5)
# Out:
# Plot with title ""

# %%
# Let's try removing the vertex shape (the circle), changing labels to blue
plot(net, vertex.shape="none", vertex.label=V(net)$name, 
     vertex.label.font=2, vertex.label.color="blue", edge.curved=0.2,
     vertex.label.cex=.5, edge.arrow.size=.1,edge.arrow.size=.1,  
     edge.color="gray85")
# Out:
# Plot with title ""

# %%
# Let's try differnet layouts by using the layout plot function:
# ?igraph::layout_ To check all layouts

# %%
# randomly placed vertices
plot(net, vertex.label=V(net)$name, edge.curved=0.2,
     vertex.label.font=2, vertex.label.color="blue",
     vertex.label.cex=.5, edge.arrow.size=.1,edge.arrow.size=.1,  
     edge.color="gray85",layout=layout_randomly)
# Out:
# Plot with title ""

# %%
# Circle layout
plot(net, vertex.label=V(net)$name, edge.curved=0.2,
     vertex.label.font=2, vertex.label.color="blue",
     vertex.label.cex=.5, edge.arrow.size=.1,edge.arrow.size=.1,  
     edge.color="gray85", layout=layout_in_circle)
# Out:
# Plot with title ""

# %%
# 3D sphere layout
plot(net, vertex.shape="none", vertex.label=V(net)$name, edge.curved=0.2,
     vertex.label.font=2, vertex.label.color="blue",
     vertex.label.cex=.5, edge.arrow.size=.1,edge.arrow.size=.1,  
     edge.color="gray85",layout=layout_randomly)
# Out:
# Plot with title ""

# %%
#lgl layout works better with big-dense networks
plot(net, vertex.label=V(net)$name, edge.curved=0.2,
     vertex.label.font=2, vertex.label.color="blue",
     vertex.label.cex=.5, edge.arrow.size=0,edge.arrow.size=0.1,  
     edge.color="gray85",layout=layout_with_lgl)
# Out:
# Plot with title ""

# %% [markdown]
# # III. Highlighting aspects of the network

# %%
# Lte's look at the weights
hist(links$weight, breaks=seq(1, max(links$weight)))
varDescribe(links$weight) # describe weights
# Problem: we have way too many links and super skeweed
# Out:
#    vars n    mean sd    median min max  skew  kurtosis
# X1 1    9817 4.91 24.95 1      1   1467 32.35 1516.69
# Plot with title "Histogram of links$weight"

# %%
# To help to visualize the network, we are going to trim all the edges with N# of connections below the mean
cut.off <- mean(links$weight) 
net.sp <- delete_edges(net, E(net)[weight<cut.off])
plot(net.sp,dge.curved=0.2, vertex.label.color="blue",
     vertex.label.cex=0.5, edge.arrow.size=0,edge.arrow.size=0.1,  
     edge.color="gray85",layout=layout_with_kk)
# Out:
# Plot with title ""

# %% [markdown]
# ### Community detection algorithms
# We are going to try to make the network map more useful by showing the communities within it.
# Community detection (by optimizing modularity over partitions) may take a long with hundres of edgeds and vertices
# A few common options:
# - **cluster_optimal**: This function calculates the optimal community structure of a graph, by maximizing the modularity measure over all possible partitions.
# - **cluster_fast_greedy**: This function tries to find dense subgraph, also called communities in graphs via directly optimizing a modularity score.
# - **cluster_walktrap**: This function tries to find densely connected subgraphs, also called communities in a graph via random walks. The idea is that short random walks tend to stay in the same community.
#
# *cluster_optimal* may take forever to run with a large graph, and *cluster_fast_greedy* only works for undirected graphs, so so we are going to try with ***cluster_walktrap*** first.
# More info here https://stackoverflow.com/questions/9471906/what-are-the-differences-between-community-detection-algorithms-in-igraph

# %%
clp <- cluster_walktrap(net)
beep(sound = 8) # this will sound when its ready

# %%
# The cluster_walktrap returns a community object
class(clp)
head(clp$membership) #here we can check the community at which each node was assigned
# Out:
# [1] "communities"
# [1]  5  5  4  5 16  5

# %%
# We can plot using the results obtained from the algorithm
# Igraph has built-in functions to plot this
#plot(clp, net, layout=layout_with_kk)
# But warning: PANDEMONIUM!
plot(clp, net, dge.curved=0.2,vertex.label.cex=0.5, 
     edge.arrow.size=0,edge.arrow.size=0.1,  
     edge.color="gray85",layout=layout_with_kk)
# Out:
# Plot with title ""

# %%
# Lets create a color pallet for the 22 communities
prettyColors <- rainbow(22, alpha = 0.8)
communityColors <- prettyColors[membership(clp)]
plot(x=1:22, y=1:22, pch=19, cex=5, col=unique(communityColors))
# Out:
# plot without title

# %%
# Now we can  plot the communities without relying on their built-in plot:
V(net)$community <- clp$membership
colrs <- adjustcolor(pal1)
plot(net, vertex.color=communityColors)
# Out:
# Plot with title ""

# %%
# To help to visualize the network, we are going to trim all the edges with N# of connections below the mean
# cut.off <- mean(links$weight) 
# net.sp <- delete_edges(net, E(net)[weight<cut.off])
plot(net.sp,dge.curved=0.2, vertex.color=communityColors,
     vertex.label.cex=0.5, edge.arrow.size=0,edge.arrow.size=0.1,  
     edge.color="gray85",layout=layout_with_kk)
# Out:
# Plot with title ""

# %%
# Function to group communities in the graph 
# Use:
# - put your community object in the community slot
# - put your graph in the network slot
# Mpre info: https://stackoverflow.com/questions/16390221/how-to-make-grouped-layout-in-igraph
edge.weights <- function(community, network, weight.within = 100, weight.between = 1) {
bridges <- crossing(communities = community, graph = network)
weights <- ifelse(test = bridges, yes = weight.between, no = weight.within)
return(weights) 
}

# %%
# Then transfer the weights to the weight slot in the nodes:
net.graph <- net
E(net.graph)$weight <- edge.weights(clp, net.graph)

# %%
# Plot with no labels, clustered by community, and nodes scaled by weight 
set.seed(28) # set seed for reproducibility
plot(x = clp, y = net.graph, edge.width = 0.1, mark.groups = NULL, ylim= c(-1, 1), xlim=c(-1,1), 
     vertex.label = NA, edge.arrow.size=0, edge.arrow.size=0.1,  edge.color = "Grey",
    col = communityColors, layout = layout_with_fr, main = "Animal's association network")
# Out:
# Plot with title "Animal's association network"

# %%
# Plot with no labels, clustered by community, and nodes at fix size
set.seed(28) # set seed for reproducibility
plot(x = clp, y = net.graph, edge.width = 0.1,  mark.border=NA,
     vertex.label = NA, edge.arrow.size=0.2, vertex.size = 5, edge.color = "Grey",
     col = communityColors, layout = layout_with_fr,  main = "Animal's association network")
# Out:
# Plot with title "Animal's association network"

# %%
# Options to plot out the graph in high resolution: https://www.r-bloggers.com/high-resolution-figures-in-r/

# Export as high resolution tiff

# Plot with no labels, clustered by community, and nodes scaled by weight 
# Export as high resolution tiff
set.seed(28) # set seed for reproducibility
tiff("plot_weighted_nodes_white_b.tiff", width =10, height = 10, units = 'in', res = 500, compression = 'none')
plot(x = clp, y = net.graph, edge.width = 0.1,  mark.border=NA,
     vertex.label = NA, edge.arrow.size=0.2, edge.color = "Grey",
     col = communityColors, layout = layout_with_fr)
dev.off()
# Out:
# png
#   2

# %%
# Export as high resolution tiff

# Plot with no labels, clustered by community, and nodes scaled by weight 
set.seed(28) # set seed for reproducibility
tiff("plot_unweighted_nodes__white_b.tiff", width =10, height = 10, units = 'in', res = 500, compression = 'none')
plot(x = clp, y = net.graph, edge.width = 0.1,  mark.border=NA,
     vertex.label = NA, edge.arrow.size=0.2, vertex.size = 5, edge.color = "Grey",
     col = communityColors, layout = layout_with_fr)
dev.off()
# Out:
# png
#   2

# %%
# Let's extract the first animal from each cluster to use it as label for the group
names = c()
for (i in 1:22) {
    names[[i]] <- paste(clp[[i]][1], ", n = ",sizes(clp)[[i]][1], sep = "")
    # append to list <- first animal in the cluster + number of animals in the cluster
}
names
class(names)
# Out:
#  [1] "pike, n = 4"      "crab, n = 2"      "canari, n = 18"   "ant, n = 19"
#  [5] "aardvark, n = 52" "polarbear, n = 5" "chickade, n = 9"  "badger, n = 42"
#  [9] "cat, n = 42"      "bluebird, n = 7"  "trout, n = 2"     "baboon, n = 49"
# [13] "wasp, n = 3"      "bass, n = 3"      "boa, n = 4"       "antelop, n = 21"
# [17] "eagl, n = 8"      "anemon, n = 1"    "catfish, n = 1"   "clam, n = 1"
# [21] "shrimp, n = 1"    "squid, n = 1"
# [1] "character"

# %%
# GRAPH 1
# Let's add leyends to the groups by picking the first animal on each cluster
# Plot with no labels, clustered by community, and nodes at fix size
set.seed(28) # set seed for reproducibility
par(bg="black") # set background to black
plot(x = clp, y = net.graph, edge.width = 0.1,  mark.border=NA, 
     vertex.label = NA, edge.arrow.size=0.2, vertex.size = 5, edge.color = "Grey",
     col = communityColors, layout=layout_with_fr)
title(main = list("Animal's association network", cex = 1,
                  col = "white", font = 2))
legend(x =-1.6 , y = 0.5, legend=levels(factor(names, levels=names)),
       col = unique(communityColors), bty = "n", pch=20 , pt.cex = 1.5, cex = 0.7, 
       text.col=unique(communityColors), horiz = FALSE, inset = c(0.1, 0.1), text.font =2)
# Out:
# Plot with title "Animal's association network"Plot with title "1"Plot with title "white"Plot with title "2"

# %%
# Let's plot out graph 1
tiff("plot_unweighted_nodes__black_b.tiff", width =12, height = 10, units = 'in', res = 500, compression = 'none')
set.seed(28) # set seed for reproducibility
par(bg="black") # set background to black
plot1 = plot(x = clp, y = net.graph, edge.width = 0.1,  mark.border=NA, 
     vertex.label = NA, edge.arrow.size=0.2, vertex.size = 5, edge.color = "Grey",
     col = communityColors, layout=layout_with_fr)
title(main = list("Animal's association network", cex = 1,
                  col = "white", font = 2))
legend(x =-1.6 , y = 0.5, legend=levels(factor(names, levels=names)),
       col = unique(communityColors), bty = "n", pch=20 , pt.cex = 1.5, cex = 0.7, 
       text.col=unique(communityColors), horiz = FALSE, inset = c(0.1, 0.1), text.font =2)
dev.off()
# Out:
# png
#   2

# %%
# GRAPH 2
# Let's add leyends to the groups by picking the first animal on each cluster
# Plot with no labels, clustered by community, and nodes scaled by weight (n# of links)
set.seed(28) # set seed for reproducibility
par(bg="black") # set background to black
plot(x = clp, y = net.graph, edge.width = 0.1,  mark.border=NA, 
     vertex.label = NA, edge.arrow.size=0.2, edge.color = "Grey",
     col = communityColors, layout=layout_with_fr)
title(main = list("Animal's association network", cex = 1,
                  col = "white", font = 2))

legend(x =-1.6 , y = 0.5, legend=levels(factor(names, levels=names)),
       col = unique(communityColors), bty = "n", pch=20 , pt.cex = 1.5, cex = 0.7, 
       text.col=unique(communityColors), horiz = FALSE, inset = c(0.1, 0.1), text.font =2)
# Out:
# Plot with title "Animal's association network"Plot with title "1"Plot with title "white"Plot with title "2"

# %%
# Let's plot out graph 2
tiff("plot_weighted_nodes__black_b.tiff", width =12, height = 10, units = 'in', res = 500, compression = 'none')
set.seed(28) # set seed for reproducibility
par(bg="black") # set background to black
plot(x = clp, y = net.graph, edge.width = 0.1,  mark.border=NA, 
     vertex.label = NA, edge.arrow.size=0.2, edge.color = "Grey",
     col = communityColors, layout=layout_with_fr)
title(main = list("Animal's association network", cex = 1,
                  col = "white", font = 2))
legend(x =-1.6 , y = 0.5, legend=levels(factor(names, levels=names)),
       col = unique(communityColors), bty = "n", pch=20 , pt.cex = 1.5, cex = 0.7, 
       text.col=unique(communityColors), horiz = FALSE, inset = c(0.1, 0.1), text.font =2)
dev.off()
# Out:
# png
#   2

# %%
# GRAPH 3
# Let's add leyends to the groups by picking the first animal on each cluster
# Plot with labels, clustered by community, and nodes at fix size
set.seed(28) # set seed for reproducibility
par(bg="black") # set background to black
plot(x = clp, y = net.graph, edge.width = 0.1,  mark.border=NA,  vertex.label.cex=0.5, 
      vertex.label.color="white", edge.arrow.size=0.2, vertex.size = 6, edge.color = "Grey",
     col = communityColors, layout=layout_with_fr)
title(main = list("Animal's association network", cex = 1,
                  col = "white", font = 2))
legend(x =-1.6 , y = 0.5, legend=levels(factor(names, levels=names)),
       col = unique(communityColors), bty = "n", pch=20 , pt.cex = 1.5, cex = 0.7, 
       text.col=unique(communityColors), horiz = FALSE, inset = c(0.1, 0.1), text.font =2)
# Out:
# Plot with title "Animal's association network"Plot with title "1"Plot with title "white"Plot with title "2"

# %%
# Let's plot out GRAPH 3
tiff("plot_unweighted_nodes__black_b_leg.tiff", width =12, height = 10, units = 'in', res = 500, compression = 'none')
set.seed(28) # set seed for reproducibility
par(bg="black") # set background to black
plot(x = clp, y = net.graph, edge.width = 0.1,  mark.border=NA,  vertex.label.cex=0.5, 
      vertex.label.color="white", edge.arrow.size=0.2, vertex.size = 6, edge.color = "Grey",
     col = communityColors, layout=layout_with_fr)
title(main = list("Animal's association network", cex = 1,
                  col = "white", font = 2))
legend(x =-1.6 , y = 0.5, legend=levels(factor(names, levels=names)),
       col = unique(communityColors), bty = "n", pch=20 , pt.cex = 1.5, cex = 0.7, 
       text.col=unique(communityColors), horiz = FALSE, inset = c(0.1, 0.1), text.font =2)
dev.off()
# Out:
# png
#   2

# %%
# GRAPH 4
# Let's add leyends to the groups by picking the first animal on each cluster|
# Plot with labels, clustered by community, and nodes scaled by weight (n# of links)
set.seed(28) # set seed for reproducibility
par(bg="black") # set background to black
plot(x = clp, y = net.graph, edge.width = 0.1,  mark.border=NA, vertex.label.cex=0.5, 
      vertex.label.color="white", edge.arrow.size=0.2, edge.color = "Grey",
     col = communityColors, layout=layout_with_fr)
title(main = list("Animal's association network", cex = 1,
                  col = "white", font = 2))
legend(x =-1.6 , y = 0.5, legend=levels(factor(names, levels=names)),
       col = unique(communityColors), bty = "n", pch=20 , pt.cex = 1.5, cex = 0.7, 
       text.col=unique(communityColors), horiz = FALSE, inset = c(0.1, 0.1), text.font =2)
# Out:
# Plot with title "Animal's association network"Plot with title "1"Plot with title "white"Plot with title "2"

# %%
# Let's plot out GRAPH 4
tiff("plot_weighted_nodes__black_b_leg.tiff", width =12, height = 10, units = 'in', res = 500, compression = 'none')
set.seed(28) # set seed for reproducibility
par(bg="black") # set background to black
plot(x = clp, y = net.graph, edge.width = 0.1,  mark.border=NA, vertex.label.cex=0.5, 
      vertex.label.color="white", edge.arrow.size=0.2, edge.color = "Grey",
     col = communityColors, layout=layout_with_fr)
title(main = list("Animal's association network", cex = 1,
                  col = "white", font = 2))
legend(x =-1.6 , y = 0.5, legend=levels(factor(names, levels=names)),
       col = unique(communityColors), bty = "n", pch=20 , pt.cex = 1.5, cex = 0.7, 
       text.col=unique(communityColors), horiz = FALSE, inset = c(0.1, 0.1), text.font =2)
dev.off()
# Out:
# png
#   2

# %%
membership(clp)
# Out:
#      aardvark         allig           ant        anteat       antelop
#             5             5             4             5            16
#     armadillo        baboon        badger           bat          bear
#             5            12             8             5            12
#        beaver       buffalo         camel        canari           cat
#             8            16            12             3             9
#       cheetah       chicken      chipmunk           cow         coyot
#            12             9             8             9            16
#      crocodil          deer           dog         eleph           elk
#             5            16             9            12            16
#          fish           fox          frog          goat          hors
#             5            16             5             9             9
#      kangaroo          lion         llama        monkei       octopus
#            12            12             9            12             5
#       ostrich        rabbit       raccoon         sheep          snak
#             5             8             8             9             5
#         tiger        turkei         whale         zebra          bird
#            12             9             5            12             5
#           boa          bull     chameleon         chimp        cougar
#            15             9             5            12            12
#       cricket      dinosaur       dolphin        donkei          duck
#             4             5             5             9             9
#           eel         egret        ferret        gerbil        giraff
#             5             3             8             8            12
#          goos        gopher       gorilla         hippo         hyena
#             9             8            12            12            12
#        iguana        insect         koala       ladybug       leopard
#             5             4            12             4            12
#        lizard          lynx        mammal          mink          moos
#             5            12             5             8            16
#      mosquito          mous       opossum         otter            ox
#             4             8             8             8             9
#         panda        parrot           pig     polarbear         puppi
#            12             3             9             6             9
#           rat        reptil         rhino        rodent         shark
#             8             5            12             8             5
#        spider      squirrel          toad         turtl       wildcat
#             4             8             5             5            12
#    wildebeest          wolf      wolverin        alpaca          eagl
#            12            16             8             9            17
#      holstein     amphibian         human       mongoos      woodpeck
#             9             5             5             8            17
#        anemon          anim         bison         lemur        tadpol
#            18             5            16             5             5
#            ap           bee         beetl        bobcat           bug
#            12             4             4            12             4
#          calf      centiped     cockroach           fly     grasshopp
#             9             4             4             4             4
#          moth  mountainlion          wasp         gazel        jaguar
#             4            12            13            12            12
#          mole       muskrat     orangutan      platypus    prairiedog
#             8             8            12            12             8
#          seal         skunk         tapir       caribou      chickade
#             5             8            12            16             7
#    chinchilla         eland           gnu   grizzlybear       hamster
#             8            12            12             6             8
#           hog          humb        impala      javelina        kitten
#             9             5            12            16             9
#  mountaingoat          mule         muled        muskox      porcupin
#            16             9            16            16             8
#      reindeer       unicorn        walrus  waterbuffalo    whitetaild
#            16            12             5            12            16
#      goldfish     guineapig       sealion          boar          gnat
#             5             8             5             9             4
#          hawk       pelican           ass          colt       catfish
#            17             5             9             9            19
#      flamingo     groundhog        marmot         quail  tasmanidevil
#             5             8             8             3             8
#        weasel     woodchuck          bass         muski          pike
#             8             8            14            14             1
#      marmoset           owl       panther         robin         shrew
#            12             3            12             7             8
#     blackbear     brownbear      bumblebe     butterfli       buzzard
#             6             6            13             4            17
#   caterpillar          coon           cub           emu        fisher
#             4             8            16             5             8
#     gilamonst      hedgehog       jackass    kodiakbear          lamb
#             5             8             9             6             9
#          loon      parakeet       penguin        person      pheasant
#             3             3             5             5             3
#       porpois          puma    timberwolf          poni        hornet
#             5            12            16             9            13
#          worm     blackbird      bluebird       bluejai        cardin
#             4             7            10            10            10
#     cockatiel          crow          flea          fowl         grous
#             3             7             4             9             3
#          gull         heron        manate         oriol      partridg
#             7             3             5            10             3
#       peacock        pigeon      salamand        seagul         snail
#             5             3             5             3             5
#       sparrow         stork       tortois        vultur      wildanim
#             7             3             5            17            12
#         cattl         finch          dove         starl          wren
#             9             7            17            10            10
#       bluegil      sturgeon     goldfinch   hummingbird    rattlesnak
#             1             1            10            17            15
#        marten         trout         bunni         crane      farmanim
#             8            11             8             5             9
#           ram       warthog        heifer       rooster         steer
#             9             5             9             9             9
#       wallabi         gecko         burro        jackal mountainsheep
#            12             5             9            12            16
#        ocelot           yak        falcon           hen      housecat
#            12            12            17             9             9
#        salmon     earthworm         dingo          swan        gibbon
#            11             5            12             9            12
#   redsquirrel          clam          crab         cobra      cockatoo
#             8            20             2            15             3
#          mare          minx           ibi      roadrunn        wombat
#             9             8             3             3            12
#       lobster         perch        shrimp        python         raven
#             2            14            21            15             7
#           doe         ermin          fawn          hare        dragon
#            16             8            16             8             5
#        osprei          sabl            ew        walley          newt
#             7             8             9             1             5
#       mallard    jackrabbit         sloth         squid          vole
#             9            12            12            22             8
